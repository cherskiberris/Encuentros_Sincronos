# %% [markdown]
# <a href="https://colab.research.google.com/github/cherskiberris/Encuentros_Sincronos/blob/main/Generador_de_Cronogramas_Escolares_(con_exportaci%C3%B3n_a_Excel).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import calendar
import datetime
import pandas as pd
import os
from collections import defaultdict
import random # Importar la biblioteca random

# Nota: Este script requiere la biblioteca pandas.
# Puedes instalarla con el comando: pip install pandas openpyxl

def generar_cronograma_mensual(materias, anio, mes, contador_encuentros):
    """
    Genera un cronograma de encuentros para un mes específico, actualizando el contador.

    Args:
        materias (list): Lista de materias a agendar para el mes.
        anio (int): El año para el cual se generará el cronograma.
        mes (int): El mes (en número) para el cual se generará el cronograma.
        contador_encuentros (defaultdict): Diccionario para llevar la cuenta de los
                                           encuentros por materia.

    Returns:
        tuple: Una tupla conteniendo dos listas:
               - cronograma_mes (list): Los encuentros agendados para el mes.
               - sin_agendar_mes (list): Las materias que no pudieron ser agendar.
    """
    # --- 1. Definición de Horarios y Constantes ---
    HORAS_DISPONIBLES = [9, 10, 11, 13, 14]
    DIAS_SEMANA = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]

    # --- 2. Inicialización de Estructuras de Datos para el mes ---
    cronograma_mes = []
    sin_agendar_mes = []
    reuniones_instructor_dia = {}
    reuniones_grado_dia = {}
    horarios_ocupados = {}

    # --- 3. Generar la Lista de Días Hábiles del Mes ---
    dias_habiles_del_mes = []
    cal = calendar.Calendar()
    for dia in cal.itermonthdates(anio, mes):
        if dia.month == mes and dia.weekday() < 5:
            dias_habiles_del_mes.append(dia)

    # --- Barajar la lista de días hábiles para distribuir los encuentros ---
    random.shuffle(dias_habiles_del_mes)

    # --- 4. Algoritmo de Asignación Mensual ---
    for materia_info in materias:
        instructor = materia_info['instructor']
        grado = materia_info['grado']
        materia_nombre = materia_info['materia']

        encuentro_agendado = False

        # Iterar sobre los días hábiles (ahora barajados)
        for dia in dias_habiles_del_mes:
            dia_str = dia.strftime('%Y-%m-%d')
            for hora in HORAS_DISPONIBLES:

                if reuniones_instructor_dia.get(instructor, {}).get(dia_str, 0) >= 2:
                    continue
                if reuniones_grado_dia.get(grado, {}).get(dia_str, 0) >= 1:
                    continue
                if hora in horarios_ocupados.get(dia_str, []):
                    continue

                # --- Asignación del Encuentro ---
                # Se encontró un espacio. Se procede a agendar.

                # Incrementar y obtener el número de encuentro para esta materia
                llave_materia = (grado, materia_nombre)
                contador_encuentros[llave_materia] += 1
                numero_encuentro = contador_encuentros[llave_materia]

                cronograma_mes.append({
                    'fecha': dia_str,
                    'dia_semana': DIAS_SEMANA[dia.weekday()],
                    'hora_inicio': f"{hora:02d}:00",
                    'hora_fin': f"{hora+1:02d}:00",
                    'instructor': instructor,
                    'materia': materia_nombre,
                    'grado': grado,
                    'encuentro_nro': numero_encuentro
                })

                # Actualizar estructuras de control
                reuniones_instructor_dia.setdefault(instructor, {}).setdefault(dia_str, 0)
                reuniones_instructor_dia[instructor][dia_str] += 1
                reuniones_grado_dia.setdefault(grado, {}).setdefault(dia_str, 0)
                reuniones_grado_dia[grado][dia_str] += 1
                horarios_ocupados.setdefault(dia_str, []).append(hora)

                encuentro_agendado = True
                break

            if encuentro_agendado:
                break

        if not encuentro_agendado:
            sin_agendar_mes.append({**materia_info, 'mes_fallido': f"{mes}-{anio}"})

    return cronograma_mes, sin_agendar_mes

def imprimir_cronograma_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Imprime el cronograma anual de forma legible en la consola."""
    periodo = f"{mes_inicio}/{anio_inicio} - {mes_fin}/{anio_fin}"
    print("\n" + "="*80)
    print(f"CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO {periodo}")
    print("="*80)

    if not cronograma:
        print("No se pudo agendar ningún encuentro.")
        return

    cronograma_ordenado = sorted(cronograma, key=lambda x: (x['fecha'], x['hora_inicio']))

    ultimo_mes_impreso = None
    for encuentro in cronograma_ordenado:
        mes_actual = datetime.datetime.strptime(encuentro['fecha'], '%Y-%m-%d').strftime('%B %Y')
        if mes_actual != ultimo_mes_impreso:
            print(f"\n\n--- {mes_actual.upper()} ---")
            ultimo_mes_impreso = mes_actual

        print(
            f"  [{encuentro['fecha']} {encuentro['hora_inicio']}] "
            f"Grado: {encuentro['grado']:<10} | "
            f"Materia: {encuentro['materia']} (Encuentro #{encuentro['encuentro_nro']}) | "
            f"Instructor: {encuentro['instructor']}"
        )

    if sin_agendar:
        print("\n" + "="*80)
        print("ATENCIÓN: Los siguientes encuentros no pudieron ser agendados:")
        print("="*80)
        for item in sin_agendar:
            print(f"- Mes: {item['mes_fallido']} | Grado: {item['grado']}, Materia: {item['materia']}, Instructor: {item['instructor']}")

def exportar_a_excel_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Exporta el cronograma anual a un archivo Excel."""
    if not cronograma:
        print("\nNo hay datos para exportar a Excel.")
        return

    datos_para_df = []
    for item in cronograma:
        datos_para_df.append({
            'Fecha': item['fecha'],
            'Hora': f"{item['hora_inicio']} - {item['hora_fin']}",
            'Grado': item['grado'],
            'Materia': item['materia'],
            'Encuentro Nro': item['encuentro_nro'],
            'Instructor': item['instructor']
        })

    df_cronograma = pd.DataFrame(datos_para_df)
    df_cronograma = df_cronograma.sort_values(by=['Fecha', 'Hora']).reset_index(drop=True)

    periodo_str = f"{anio_inicio}-{anio_fin if anio_inicio == anio_fin else str(anio_fin)[-2:]}"
    nombre_archivo = f"Cronograma_Anual_{periodo_str}.xlsx"

    with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:
        df_cronograma.to_excel(writer, sheet_name='Cronograma Anual', index=False)
        if sin_agendar:
            df_sin_agendar = pd.DataFrame(sin_agendar)
            df_sin_agendar.to_excel(writer, sheet_name='No Agendados', index=False)

    print("\n" + "="*80)
    print(f"✅ ¡Cronograma anual exportado exitosamente a '{nombre_archivo}'!")
    print("="*80)

# --- EJECUCIÓN PRINCIPAL ---
if __name__ == "__main__":
    lista_de_materias = [
        {'instructor': 'Yosibel Garcia', 'materia': 'Cívica', 'grado': '7mo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '7mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '7no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '7mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Lideres Emergentes', 'grado': '7mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '8vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '8vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '8vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación para la Salud', 'grado': '8vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '9no grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Álgebra I', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Biología', 'grado': '9no grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia de USA', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '10mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Geometría', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Ética', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '10mo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Orientación Vocacional', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia Univeral', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Actuación', 'grado': '10mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '11vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Algebra II', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '11vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales y Gestión del Dinero', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia del Arte', 'grado': '11vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias de la Tierra', 'grado': '11vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '12vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Ciencias de la Computación', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '12vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Gobierno de USA', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Liderazgo', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Economía', 'grado': '12vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Química', 'grado': '12vo grado'}
    ]

    # --- Definir el período del año escolar ---
    ANIO_INICIO, MES_INICIO = 2025, 8  # Agosto 2025
    ANIO_FIN, MES_FIN = 2026, 5      # Mayo 2026

    # --- Preparar estructuras para el ciclo anual ---
    cronograma_anual_completo = []
    no_agendados_total = []
    contador_general_encuentros = defaultdict(int) # Usamos defaultdict para simplificar

    print("Iniciando generación de cronograma para el año escolar...")

    # --- Iterar a través de cada mes del año escolar ---
    anio_actual, mes_actual = ANIO_INICIO, MES_INICIO
    while (anio_actual, mes_actual) <= (ANIO_FIN, MES_FIN):
        print(f"\nProcesando mes: {mes_actual}/{anio_actual}...")

        cronograma_del_mes, no_agendados_del_mes = generar_cronograma_mensual(
            lista_de_materias, anio_actual, mes_actual, contador_general_encuentros
        )

        cronograma_anual_completo.extend(cronograma_del_mes)
        no_agendados_total.extend(no_agendados_del_mes)

        # Avanzar al siguiente mes
        mes_actual += 1
        if mes_actual > 12:
            mes_actual = 1
            anio_actual += 1

    # --- Mostrar y exportar resultados finales ---
    imprimir_cronograma_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
    exportar_a_excel_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
# Out:
# Iniciando generación de cronograma para el año escolar...
#
# Procesando mes: 8/2025...
#
# Procesando mes: 9/2025...
#
# Procesando mes: 10/2025...
#
# Procesando mes: 11/2025...
#
# Procesando mes: 12/2025...
#
# Procesando mes: 1/2026...
#
# Procesando mes: 2/2026...
#
# Procesando mes: 3/2026...
#
# Procesando mes: 4/2026...
#
# Procesando mes: 5/2026...
#
# ================================================================================
# CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO 8/2025 - 5/2026
# ================================================================================
#
#
# --- AUGUST 2025 ---
#   [2025-08-01 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-05 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-05 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-05 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-05 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-05 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-06 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-06 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-06 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-06 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-06 14:00] Grado: 11vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-08 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-08 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-08 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-08 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-08 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-12 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-12 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-12 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-12 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-12 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-13 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-13 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-14 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-15 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-15 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-15 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-15 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-15 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-19 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-19 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-20 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-20 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-20 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-20 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-20 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-22 09:00] Grado: 12vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-26 09:00] Grado: 12vo grado | Materia: Química (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-27 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-27 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-27 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-29 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #1) | Instructor: Alvaro Gonzalez
#
#
# --- SEPTEMBER 2025 ---
#   [2025-09-03 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-03 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-08 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-08 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-08 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-08 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-08 14:00] Grado: 11vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-11 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-12 09:00] Grado: 12vo grado | Materia: Química (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-15 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-15 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-15 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-15 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-15 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-17 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-17 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-17 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-18 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-18 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-18 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-18 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-18 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-22 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-22 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-22 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-22 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-22 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-23 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-23 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-24 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-24 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-24 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-24 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-24 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-26 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-29 09:00] Grado: 12vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-30 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-30 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-30 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-30 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-30 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#
#
# --- OCTOBER 2025 ---
#   [2025-10-01 09:00] Grado: 12vo grado | Materia: Química (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-02 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-02 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-02 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-02 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-02 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-06 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-06 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-06 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-06 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-06 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-07 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-07 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-07 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-07 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-07 14:00] Grado: 11vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-08 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-08 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-08 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-08 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-08 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-09 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-09 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-10 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-16 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-16 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-16 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-17 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-20 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-20 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-21 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-21 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-21 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-21 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-21 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-23 09:00] Grado: 12vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-29 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-30 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-30 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-30 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-30 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-30 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #3) | Instructor: Freddy Martinez
#
#
# --- NOVEMBER 2025 ---
#   [2025-11-03 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-03 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-05 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-05 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-05 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-06 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-06 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-06 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-06 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-06 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-07 09:00] Grado: 12vo grado | Materia: Química (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-12 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-17 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-17 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-17 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-17 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-17 14:00] Grado: 11vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-18 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-18 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-18 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-18 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-18 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-19 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-19 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-20 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-20 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-20 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-20 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-20 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-21 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-21 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-21 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-21 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-21 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-26 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-26 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-26 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-26 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-26 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-27 09:00] Grado: 12vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-28 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #4) | Instructor: Yosibel Garcia
#
#
# --- DECEMBER 2025 ---
#   [2025-12-02 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-02 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-03 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-03 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-03 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-08 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-08 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-08 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-08 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-08 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-09 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-10 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-11 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-11 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-11 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-11 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-11 14:00] Grado: 11vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-12 09:00] Grado: 12vo grado | Materia: Química (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-15 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-15 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-15 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-15 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-15 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-16 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-16 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-18 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-18 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-18 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-18 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-18 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-22 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-22 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-22 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-22 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-22 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-23 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-23 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-23 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-23 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-23 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-29 09:00] Grado: 12vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-31 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #5) | Instructor: Alvaro Gonzalez
#
#
# --- JANUARY 2026 ---
#   [2026-01-01 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-01 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-01 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-01 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-01 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-02 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-02 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-02 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-02 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-02 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-05 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-05 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-05 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-05 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-05 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-07 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-08 09:00] Grado: 12vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-09 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-09 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-12 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-12 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-12 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-12 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-12 14:00] Grado: 11vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-13 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-15 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-16 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-16 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-16 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-16 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-16 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-20 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-20 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-22 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-22 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-22 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-22 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-22 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-23 09:00] Grado: 12vo grado | Materia: Química (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-27 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-27 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-27 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#
#
# --- FEBRUARY 2026 ---
#   [2026-02-03 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-05 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-05 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-05 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-05 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-05 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-09 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-09 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-09 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-09 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-09 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-10 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-10 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-10 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-10 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-10 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-11 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-11 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-13 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-13 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-13 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-13 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-17 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-17 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-17 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-17 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-17 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-18 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-19 09:00] Grado: 12vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-23 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-23 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-23 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-23 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-23 14:00] Grado: 11vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-24 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-24 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-24 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-25 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-25 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-27 09:00] Grado: 12vo grado | Materia: Química (Encuentro #7) | Instructor: Ivonne Blanco
#
#
# --- MARCH 2026 ---
#   [2026-03-02 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-02 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-02 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-02 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-02 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-03 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-03 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-03 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-03 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-03 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-05 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-05 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-05 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-05 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-05 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-06 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-09 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-09 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-10 09:00] Grado: 12vo grado | Materia: Química (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-11 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-12 09:00] Grado: 12vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-20 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-20 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-20 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-20 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-20 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-23 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-23 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-23 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-23 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-23 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-24 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-24 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-27 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-27 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-27 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-31 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-31 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-31 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-31 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-31 14:00] Grado: 11vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#
#
# --- APRIL 2026 ---
#   [2026-04-03 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-07 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-07 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-07 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-07 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-07 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-08 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-08 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-09 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-09 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-09 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-09 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-09 14:00] Grado: 11vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-14 09:00] Grado: 12vo grado | Materia: Química (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-16 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-16 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-16 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-17 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-17 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-17 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-17 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-17 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-20 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-21 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-22 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-22 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-22 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-22 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-22 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-23 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-23 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-23 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-23 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-23 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-24 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-24 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-28 09:00] Grado: 12vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-30 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-30 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-30 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-30 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-30 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#
#
# --- MAY 2026 ---
#   [2026-05-01 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-01 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-06 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-08 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-11 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-11 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-11 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-11 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-11 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-13 09:00] Grado: 12vo grado | Materia: Química (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-14 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-14 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-14 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-14 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-14 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-15 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-18 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-18 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-18 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-18 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-18 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-19 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-19 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-19 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-19 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-19 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-20 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-20 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-20 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-20 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-20 14:00] Grado: 11vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-22 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-22 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-22 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-27 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-27 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-28 09:00] Grado: 12vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-29 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-29 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-29 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-29 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-29 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#
# ================================================================================
# ✅ ¡Cronograma anual exportado exitosamente a 'Cronograma_Anual_2025-26.xlsx'!
# ================================================================================

# %%
import calendar
import datetime
import pandas as pd
import os
from collections import defaultdict
import random # Importar la biblioteca random

# Nota: Este script requiere la biblioteca pandas.
# Puedes instalarla con el comando: pip install pandas openpyxl

def generar_cronograma_mensual(materias, anio, mes, contador_encuentros):
    """
    Genera un cronograma de encuentros para un mes específico, actualizando el contador.

    Args:
        materias (list): Lista de materias a agendar para el mes.
        anio (int): El año para el cual se generará el cronograma.
        mes (int): El mes (en número) para el cual se generará el cronograma.
        contador_encuentros (defaultdict): Diccionario para llevar la cuenta de los
                                           encuentros por materia.

    Returns:
        tuple: Una tupla conteniendo dos listas:
               - cronograma_mes (list): Los encuentros agendados para el mes.
               - sin_agendar_mes (list): Las materias que no pudieron ser agendar.
    """
    # --- 1. Definición de Horarios y Constantes ---
    HORAS_DISPONIBLES = [9, 10, 11, 13, 14]
    DIAS_SEMANA = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]

    # --- 2. Inicialización de Estructuras de Datos para el mes ---
    cronograma_mes = []
    sin_agendar_mes = []
    reuniones_instructor_dia = {}
    reuniones_grado_dia = {}
    horarios_ocupados = {}

    # --- 3. Generar la Lista de Días Hábiles del Mes ---
    dias_habiles_del_mes = []
    cal = calendar.Calendar()
    for dia in cal.itermonthdates(anio, mes):
        if dia.month == mes and dia.weekday() < 5:
            dias_habiles_del_mes.append(dia)

    # --- Barajar la lista de días hábiles para distribuir los encuentros ---
    random.shuffle(dias_habiles_del_mes)

    # --- 4. Algoritmo de Asignación Mensual ---
    for materia_info in materias:
        instructor = materia_info['instructor']
        grado = materia_info['grado']
        materia_nombre = materia_info['materia']

        encuentro_agendado = False

        # Iterar sobre los días hábiles (ahora barajados)
        for dia in dias_habiles_del_mes:
            dia_str = dia.strftime('%Y-%m-%d')
            for hora in HORAS_DISPONIBLES:

                if reuniones_instructor_dia.get(instructor, {}).get(dia_str, 0) >= 2:
                    continue
                if reuniones_grado_dia.get(grado, {}).get(dia_str, 0) >= 1:
                    continue
                if hora in horarios_ocupados.get(dia_str, []):
                    continue

                # --- Asignación del Encuentro ---
                # Se encontró un espacio. Se procede a agendar.

                # Incrementar y obtener el número de encuentro para esta materia
                llave_materia = (grado, materia_nombre)
                contador_encuentros[llave_materia] += 1
                numero_encuentro = contador_encuentros[llave_materia]

                cronograma_mes.append({
                    'fecha': dia_str,
                    'dia_semana': DIAS_SEMANA[dia.weekday()],
                    'hora_inicio': f"{hora:02d}:00",
                    'hora_fin': f"{hora+1:02d}:00",
                    'instructor': instructor,
                    'materia': materia_nombre,
                    'grado': grado,
                    'encuentro_nro': numero_encuentro
                })

                # Actualizar estructuras de control
                reuniones_instructor_dia.setdefault(instructor, {}).setdefault(dia_str, 0)
                reuniones_instructor_dia[instructor][dia_str] += 1
                reuniones_grado_dia.setdefault(grado, {}).setdefault(dia_str, 0)
                reuniones_grado_dia[grado][dia_str] += 1
                horarios_ocupados.setdefault(dia_str, []).append(hora)

                encuentro_agendado = True
                break

            if encuentro_agendado:
                break

        if not encuentro_agendado:
            sin_agendar_mes.append({**materia_info, 'mes_fallido': f"{mes}-{anio}"})

    return cronograma_mes, sin_agendar_mes

def imprimir_cronograma_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Imprime el cronograma anual de forma legible en la consola."""
    periodo = f"{mes_inicio}/{anio_inicio} - {mes_fin}/{anio_fin}"
    print("\n" + "="*80)
    print(f"CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO {periodo}")
    print("="*80)

    if not cronograma:
        print("No se pudo agendar ningún encuentro.")
        return

    cronograma_ordenado = sorted(cronograma, key=lambda x: (x['fecha'], x['hora_inicio']))

    ultimo_mes_impreso = None
    for encuentro in cronograma_ordenado:
        mes_actual = datetime.datetime.strptime(encuentro['fecha'], '%Y-%m-%d').strftime('%B %Y')
        if mes_actual != ultimo_mes_impreso:
            print(f"\n\n--- {mes_actual.upper()} ---")
            ultimo_mes_impreso = mes_actual

        print(
            f"  [{encuentro['fecha']} {encuentro['hora_inicio']}] "
            f"Grado: {encuentro['grado']:<10} | "
            f"Materia: {encuentro['materia']} (Encuentro #{encuentro['encuentro_nro']}) | "
            f"Instructor: {encuentro['instructor']}"
        )

    if sin_agendar:
        print("\n" + "="*80)
        print("ATENCIÓN: Los siguientes encuentros no pudieron ser agendados:")
        print("="*80)
        for item in sin_agendar:
            print(f"- Mes: {item['mes_fallido']} | Grado: {item['grado']}, Materia: {item['materia']}, Instructor: {item['instructor']}")

def exportar_a_excel_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Exporta el cronograma anual a un archivo Excel."""
    if not cronograma:
        print("\nNo hay datos para exportar a Excel.")
        return

    datos_para_df = []
    for item in cronograma:
        datos_para_df.append({
            'Fecha': item['fecha'],
            'Hora': f"{item['hora_inicio']} - {item['hora_fin']}",
            'Grado': item['grado'],
            'Materia': item['materia'],
            'Encuentro Nro': item['encuentro_nro'],
            'Instructor': item['instructor']
        })

    df_cronograma = pd.DataFrame(datos_para_df)
    df_cronograma = df_cronograma.sort_values(by=['Fecha', 'Hora']).reset_index(drop=True)

    periodo_str = f"{anio_inicio}-{anio_fin if anio_inicio == anio_fin else str(anio_fin)[-2:]}"
    nombre_archivo = f"Cronograma_Anual_{periodo_str}.xlsx"

    with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:
        df_cronograma.to_excel(writer, sheet_name='Cronograma Anual', index=False)
        if sin_agendar:
            df_sin_agendar = pd.DataFrame(sin_agendar)
            df_sin_agendar.to_excel(writer, sheet_name='No Agendados', index=False)

    print("\n" + "="*80)
    print(f"✅ ¡Cronograma anual exportado exitosamente a '{nombre_archivo}'!")
    print("="*80)

# --- EJECUCIÓN PRINCIPAL ---
if __name__ == "__main__":
    lista_de_materias = [
        {'instructor': 'Yosibel Garcia', 'materia': 'Cívica', 'grado': '7mo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '7mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '7no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '7mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Lideres Emergentes', 'grado': '7mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '8vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '8vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '8vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación para la Salud', 'grado': '8vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '9no grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Álgebra I', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Biología', 'grado': '9no grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia de USA', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '10mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Geometría', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Ética', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '10mo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Orientación Vocacional', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia Univeral', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Actuación', 'grado': '10mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '11vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Algebra II', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '11vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales y Gestión del Dinero', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia del Arte', 'grado': '11vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias de la Tierra', 'grado': '11vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '12vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Ciencias de la Computación', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '12vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Gobierno de USA', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Liderazgo', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Economía', 'grado': '12vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Química', 'grado': '12vo grado'}
    ]

    # --- Definir el período del año escolar ---
    ANIO_INICIO, MES_INICIO = 2025, 8  # Agosto 2025
    ANIO_FIN, MES_FIN = 2026, 5      # Mayo 2026

    # --- Preparar estructuras para el ciclo anual ---
    cronograma_anual_completo = []
    no_agendados_total = []
    contador_general_encuentros = defaultdict(int) # Usamos defaultdict para simplificar

    print("Iniciando generación de cronograma para el año escolar...")

    # --- Iterar a través de cada mes del año escolar ---
    anio_actual, mes_actual = ANIO_INICIO, MES_INICIO
    while (anio_actual, mes_actual) <= (ANIO_FIN, MES_FIN):
        print(f"\nProcesando mes: {mes_actual}/{anio_actual}...")

        cronograma_del_mes, no_agendados_del_mes = generar_cronograma_mensual(
            lista_de_materias, anio_actual, mes_actual, contador_general_encuentros
        )

        cronograma_anual_completo.extend(cronograma_del_mes)
        no_agendados_total.extend(no_agendados_del_mes)

        # Avanzar al siguiente mes
        mes_actual += 1
        if mes_actual > 12:
            mes_actual = 1
            anio_actual += 1

    # --- Mostrar y exportar resultados finales ---
    imprimir_cronograma_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
    exportar_a_excel_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
# Out:
# Iniciando generación de cronograma para el año escolar...
#
# Procesando mes: 8/2025...
#
# Procesando mes: 9/2025...
#
# Procesando mes: 10/2025...
#
# Procesando mes: 11/2025...
#
# Procesando mes: 12/2025...
#
# Procesando mes: 1/2026...
#
# Procesando mes: 2/2026...
#
# Procesando mes: 3/2026...
#
# Procesando mes: 4/2026...
#
# Procesando mes: 5/2026...
#
# ================================================================================
# CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO 8/2025 - 5/2026
# ================================================================================
#
#
# --- AUGUST 2025 ---
#   [2025-08-01 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-01 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-01 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-01 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-01 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-05 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-05 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-05 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-05 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-05 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-07 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-07 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-07 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-08 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-08 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-08 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-08 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-08 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-12 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-13 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-14 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-14 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-14 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-14 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-14 14:00] Grado: 11vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-18 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-18 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-20 09:00] Grado: 12vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-21 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-21 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-21 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-21 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-21 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-22 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-22 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-22 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-22 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-22 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-26 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-26 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-27 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-28 09:00] Grado: 12vo grado | Materia: Química (Encuentro #1) | Instructor: Ivonne Blanco
#
#
# --- SEPTEMBER 2025 ---
#   [2025-09-01 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-01 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-01 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-01 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-01 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-04 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-04 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-05 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-08 09:00] Grado: 12vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-09 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-09 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-09 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-09 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-09 14:00] Grado: 11vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-10 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-10 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-10 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-10 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-10 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-12 09:00] Grado: 12vo grado | Materia: Química (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-15 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-16 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-16 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-16 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-16 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-16 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-18 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-18 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-18 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-18 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-18 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-19 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-23 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-23 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-23 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-23 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-23 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-26 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-26 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-26 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-29 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-29 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #2) | Instructor: Freddy Martinez
#
#
# --- OCTOBER 2025 ---
#   [2025-10-02 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-02 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-03 09:00] Grado: 12vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-08 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-10 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-10 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-10 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-10 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-10 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-13 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-13 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-13 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-13 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-13 14:00] Grado: 11vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-14 09:00] Grado: 12vo grado | Materia: Química (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-15 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-17 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-17 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-17 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-17 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-17 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-23 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-23 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-23 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-24 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-24 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-24 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-24 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-24 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-28 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-28 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-29 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-30 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-30 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-30 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-30 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-30 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-31 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-31 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-31 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-31 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-31 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #3) | Instructor: Alvaro Gonzalez
#
#
# --- NOVEMBER 2025 ---
#   [2025-11-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-05 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-05 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-06 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-07 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-07 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-07 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-07 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-07 14:00] Grado: 11vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-10 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-10 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-10 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-11 09:00] Grado: 12vo grado | Materia: Química (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-12 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-17 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-17 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-17 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-17 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-17 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-18 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-18 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-21 09:00] Grado: 12vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-24 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-24 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-24 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-24 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-24 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-25 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-25 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-25 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-25 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-25 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-27 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-27 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-27 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-27 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-27 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-28 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-28 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-28 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-28 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-28 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#
#
# --- DECEMBER 2025 ---
#   [2025-12-01 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-01 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-02 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-02 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-03 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-03 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-03 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-03 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-03 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-05 09:00] Grado: 12vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-08 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-08 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-08 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-08 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-08 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-09 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-11 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-17 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-17 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-17 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-18 09:00] Grado: 12vo grado | Materia: Química (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-22 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-22 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-22 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-22 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-22 14:00] Grado: 11vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-23 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-23 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-23 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-23 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-23 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-24 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-25 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-25 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-25 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-25 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-25 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-26 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-26 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-26 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-26 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-26 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#
#
# --- JANUARY 2026 ---
#   [2026-01-01 09:00] Grado: 12vo grado | Materia: Química (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-02 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-02 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-02 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-02 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-02 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-08 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-09 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-09 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-12 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-12 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-13 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-13 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-13 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-13 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-13 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-16 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-16 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-16 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-16 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-16 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-19 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-19 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-19 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-19 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-19 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-21 09:00] Grado: 12vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-23 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-26 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-28 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-28 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-28 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-29 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-29 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-29 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-29 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-29 14:00] Grado: 11vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-30 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-30 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-30 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-30 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-30 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#
#
# --- FEBRUARY 2026 ---
#   [2026-02-02 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-02 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-05 09:00] Grado: 12vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-09 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-09 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-09 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-09 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-09 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-10 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-10 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-10 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-10 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-10 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-16 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-16 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-16 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-16 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-16 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-17 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-17 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-18 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-18 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-18 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-18 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-18 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-19 09:00] Grado: 12vo grado | Materia: Química (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-20 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-23 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-24 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-24 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-24 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-24 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-24 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-25 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-25 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-25 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-25 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-25 14:00] Grado: 11vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-26 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-26 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-26 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#
#
# --- MARCH 2026 ---
#   [2026-03-03 09:00] Grado: 12vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-09 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-09 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-10 09:00] Grado: 12vo grado | Materia: Química (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-11 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-11 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-12 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-12 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-12 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-12 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-12 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-13 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-16 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-16 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-16 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-16 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-16 14:00] Grado: 11vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-19 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-19 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-19 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-19 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-19 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-20 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-20 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-20 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-20 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-20 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-23 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-24 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-24 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-24 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-24 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-24 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-25 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-27 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-27 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-27 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-30 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-30 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-30 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-30 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-30 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#
#
# --- APRIL 2026 ---
#   [2026-04-01 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-01 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-02 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-07 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-07 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-07 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-07 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-07 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-08 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-08 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-08 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-08 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-08 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-09 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-09 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-09 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-10 09:00] Grado: 12vo grado | Materia: Química (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-13 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-17 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-17 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-17 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-17 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-17 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-20 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-22 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-22 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-22 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-22 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-22 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-23 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-23 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-23 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-23 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-23 14:00] Grado: 11vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-24 09:00] Grado: 12vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-28 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-28 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-28 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-28 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-28 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-30 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-30 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #9) | Instructor: Freddy Martinez
#
#
# --- MAY 2026 ---
#   [2026-05-01 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-04 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-04 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-04 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-04 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-04 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-05 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-05 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-05 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-05 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-05 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-11 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-11 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-11 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-12 09:00] Grado: 12vo grado | Materia: Química (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-13 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-13 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-13 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-13 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-13 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-15 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-15 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-15 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-15 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-15 14:00] Grado: 11vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-19 09:00] Grado: 12vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-20 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-20 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-20 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-20 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-20 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-21 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-21 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-22 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-22 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-22 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-22 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-22 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-25 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-25 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-27 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-29 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #10) | Instructor: Alvaro Gonzalez
#
# ================================================================================
# ✅ ¡Cronograma anual exportado exitosamente a 'Cronograma_Anual_2025-26.xlsx'!
# ================================================================================

# %%
import calendar
import datetime
import pandas as pd
import os
from collections import defaultdict
import random # Importar la biblioteca random

# Nota: Este script requiere la biblioteca pandas.
# Puedes instalarla con el comando: pip install pandas openpyxl

def generar_cronograma_mensual(materias, anio, mes, contador_encuentros):
    """
    Genera un cronograma de encuentros para un mes específico, actualizando el contador.

    Args:
        materias (list): Lista de materias a agendar para el mes.
        anio (int): El año para el cual se generará el cronograma.
        mes (int): El mes (en número) para el cual se generará el cronograma.
        contador_encuentros (defaultdict): Diccionario para llevar la cuenta de los
                                           encuentros por materia.

    Returns:
        tuple: Una tupla conteniendo dos listas:
               - cronograma_mes (list): Los encuentros agendados para el mes.
               - sin_agendar_mes (list): Las materias que no pudieron ser agendar.
    """
    # --- 1. Definición de Horarios y Constantes ---
    HORAS_DISPONIBLES = [9, 10, 11, 13, 14]
    DIAS_SEMANA = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]

    # --- 2. Inicialización de Estructuras de Datos para el mes ---
    cronograma_mes = []
    sin_agendar_mes = []
    reuniones_instructor_dia = {}
    reuniones_grado_dia = {}
    horarios_ocupados = {}

    # --- 3. Generar la Lista de Días Hábiles del Mes ---
    dias_habiles_del_mes = []
    cal = calendar.Calendar()
    for dia in cal.itermonthdates(anio, mes):
        if dia.month == mes and dia.weekday() < 5:
            dias_habiles_del_mes.append(dia)

    # --- Barajar la lista de días hábiles para distribuir los encuentros ---
    random.shuffle(dias_habiles_del_mes)

    # --- 4. Algoritmo de Asignación Mensual ---
    for materia_info in materias:
        instructor = materia_info['instructor']
        grado = materia_info['grado']
        materia_nombre = materia_info['materia']

        encuentro_agendado = False

        # Iterar sobre los días hábiles (ahora barajados)
        for dia in dias_habiles_del_mes:
            dia_str = dia.strftime('%Y-%m-%d')
            for hora in HORAS_DISPONIBLES:

                if reuniones_instructor_dia.get(instructor, {}).get(dia_str, 0) >= 2:
                    continue
                if reuniones_grado_dia.get(grado, {}).get(dia_str, 0) >= 1:
                    continue
                if hora in horarios_ocupados.get(dia_str, []):
                    continue

                # --- Asignación del Encuentro ---
                # Se encontró un espacio. Se procede a agendar.

                # Incrementar y obtener el número de encuentro para esta materia
                llave_materia = (grado, materia_nombre)
                contador_encuentros[llave_materia] += 1
                numero_encuentro = contador_encuentros[llave_materia]

                cronograma_mes.append({
                    'fecha': dia_str,
                    'dia_semana': DIAS_SEMANA[dia.weekday()],
                    'hora_inicio': f"{hora:02d}:00",
                    'hora_fin': f"{hora+1:02d}:00",
                    'instructor': instructor,
                    'materia': materia_nombre,
                    'grado': grado,
                    'encuentro_nro': numero_encuentro
                })

                # Actualizar estructuras de control
                reuniones_instructor_dia.setdefault(instructor, {}).setdefault(dia_str, 0)
                reuniones_instructor_dia[instructor][dia_str] += 1
                reuniones_grado_dia.setdefault(grado, {}).setdefault(dia_str, 0)
                reuniones_grado_dia[grado][dia_str] += 1
                horarios_ocupados.setdefault(dia_str, []).append(hora)

                encuentro_agendado = True
                break

            if encuentro_agendado:
                break

        if not encuentro_agendado:
            sin_agendar_mes.append({**materia_info, 'mes_fallido': f"{mes}-{anio}"})

    return cronograma_mes, sin_agendar_mes

def imprimir_cronograma_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Imprime el cronograma anual de forma legible en la consola."""
    periodo = f"{mes_inicio}/{anio_inicio} - {mes_fin}/{anio_fin}"
    print("\n" + "="*80)
    print(f"CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO {periodo}")
    print("="*80)

    if not cronograma:
        print("No se pudo agendar ningún encuentro.")
        return

    cronograma_ordenado = sorted(cronograma, key=lambda x: (x['fecha'], x['hora_inicio']))

    ultimo_mes_impreso = None
    for encuentro in cronograma_ordenado:
        mes_actual = datetime.datetime.strptime(encuentro['fecha'], '%Y-%m-%d').strftime('%B %Y')
        if mes_actual != ultimo_mes_impreso:
            print(f"\n\n--- {mes_actual.upper()} ---")
            ultimo_mes_impreso = mes_actual

        print(
            f"  [{encuentro['fecha']} {encuentro['hora_inicio']}] "
            f"Grado: {encuentro['grado']:<10} | "
            f"Materia: {encuentro['materia']} (Encuentro #{encuentro['encuentro_nro']}) | "
            f"Instructor: {encuentro['instructor']}"
        )

    if sin_agendar:
        print("\n" + "="*80)
        print("ATENCIÓN: Los siguientes encuentros no pudieron ser agendados:")
        print("="*80)
        for item in sin_agendar:
            print(f"- Mes: {item['mes_fallido']} | Grado: {item['grado']}, Materia: {item['materia']}, Instructor: {item['instructor']}")

def exportar_a_excel_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Exporta el cronograma anual a un archivo Excel."""
    if not cronograma:
        print("\nNo hay datos para exportar a Excel.")
        return

    datos_para_df = []
    for item in cronograma:
        datos_para_df.append({
            'Fecha': item['fecha'],
            'Hora': f"{item['hora_inicio']} - {item['hora_fin']}",
            'Grado': item['grado'],
            'Materia': item['materia'],
            'Encuentro Nro': item['encuentro_nro'],
            'Instructor': item['instructor']
        })

    df_cronograma = pd.DataFrame(datos_para_df)
    df_cronograma = df_cronograma.sort_values(by=['Fecha', 'Hora']).reset_index(drop=True)

    periodo_str = f"{anio_inicio}-{anio_fin if anio_inicio == anio_fin else str(anio_fin)[-2:]}"
    nombre_archivo = f"Cronograma_Anual_{periodo_str}.xlsx"

    with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:
        df_cronograma.to_excel(writer, sheet_name='Cronograma Anual', index=False)
        if sin_agendar:
            df_sin_agendar = pd.DataFrame(sin_agendar)
            df_sin_agendar.to_excel(writer, sheet_name='No Agendados', index=False)

    print("\n" + "="*80)
    print(f"✅ ¡Cronograma anual exportado exitosamente a '{nombre_archivo}'!")
    print("="*80)

# --- EJECUCIÓN PRINCIPAL ---
if __name__ == "__main__":
    lista_de_materias = [
        {'instructor': 'Yosibel Garcia', 'materia': 'Cívica', 'grado': '7mo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '7mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '7no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '7mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Lideres Emergentes', 'grado': '7mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '8vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '8vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '8vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación para la Salud', 'grado': '8vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '9no grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Álgebra I', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Biología', 'grado': '9no grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia de USA', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '10mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Geometría', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Ética', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '10mo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Orientación Vocacional', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia Univeral', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Actuación', 'grado': '10mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '11vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Algebra II', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '11vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales y Gestión del Dinero', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia del Arte', 'grado': '11vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias de la Tierra', 'grado': '11vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '12vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Ciencias de la Computación', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '12vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Gobierno de USA', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Liderazgo', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Economía', 'grado': '12vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Química', 'grado': '12vo grado'}
    ]

    # --- Definir el período del año escolar ---
    ANIO_INICIO, MES_INICIO = 2025, 8  # Agosto 2025
    ANIO_FIN, MES_FIN = 2026, 5      # Mayo 2026

    # --- Preparar estructuras para el ciclo anual ---
    cronograma_anual_completo = []
    no_agendados_total = []
    contador_general_encuentros = defaultdict(int) # Usamos defaultdict para simplificar

    print("Iniciando generación de cronograma para el año escolar...")

    # --- Iterar a través de cada mes del año escolar ---
    anio_actual, mes_actual = ANIO_INICIO, MES_INICIO
    while (anio_actual, mes_actual) <= (ANIO_FIN, MES_FIN):
        print(f"\nProcesando mes: {mes_actual}/{anio_actual}...")

        cronograma_del_mes, no_agendados_del_mes = generar_cronograma_mensual(
            lista_de_materias, anio_actual, mes_actual, contador_general_encuentros
        )

        cronograma_anual_completo.extend(cronograma_del_mes)
        no_agendados_total.extend(no_agendados_del_mes)

        # Avanzar al siguiente mes
        mes_actual += 1
        if mes_actual > 12:
            mes_actual = 1
            anio_actual += 1

    # --- Mostrar y exportar resultados finales ---
    imprimir_cronograma_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
    exportar_a_excel_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
# Out:
# Iniciando generación de cronograma para el año escolar...
#
# Procesando mes: 8/2025...
#
# Procesando mes: 9/2025...
#
# Procesando mes: 10/2025...
#
# Procesando mes: 11/2025...
#
# Procesando mes: 12/2025...
#
# Procesando mes: 1/2026...
#
# Procesando mes: 2/2026...
#
# Procesando mes: 3/2026...
#
# Procesando mes: 4/2026...
#
# Procesando mes: 5/2026...
#
# ================================================================================
# CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO 8/2025 - 5/2026
# ================================================================================
#
#
# --- AUGUST 2025 ---
#   [2025-08-01 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-05 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-06 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-06 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-06 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-06 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-06 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-07 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-07 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-07 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-07 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-07 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-08 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-08 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-08 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-12 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-12 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-13 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-18 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-18 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-18 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-18 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-18 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-19 09:00] Grado: 12vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-20 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-20 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-20 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-20 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-20 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-22 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-22 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-26 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-26 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-26 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-26 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-26 14:00] Grado: 11vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-27 09:00] Grado: 12vo grado | Materia: Química (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-28 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-28 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-28 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-28 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-28 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#
#
# --- SEPTEMBER 2025 ---
#   [2025-09-01 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-01 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-01 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-01 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-01 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-02 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-02 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-02 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-02 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-02 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-05 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-05 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-09 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-11 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-11 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-11 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-12 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-12 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-12 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-12 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-12 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-15 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-17 09:00] Grado: 12vo grado | Materia: Química (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-18 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-18 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-18 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-18 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-18 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-19 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-19 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-19 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-19 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-19 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-22 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-22 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-23 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-24 09:00] Grado: 12vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-30 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-30 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-30 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-30 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-30 14:00] Grado: 11vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#
#
# --- OCTOBER 2025 ---
#   [2025-10-01 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-01 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-03 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-03 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-07 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-07 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-07 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-07 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-07 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-15 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-15 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-15 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-15 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-15 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-16 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-17 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-17 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-17 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-20 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-21 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-21 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-21 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-21 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-21 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-22 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-22 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-22 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-22 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-22 14:00] Grado: 11vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-23 09:00] Grado: 12vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-27 09:00] Grado: 12vo grado | Materia: Química (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-28 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-29 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-29 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-29 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-29 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-29 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-30 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-30 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-30 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-30 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-30 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#
#
# --- NOVEMBER 2025 ---
#   [2025-11-03 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-03 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-04 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-04 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-04 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-04 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-04 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-05 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-06 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-07 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-10 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-10 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-10 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-10 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-10 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-11 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-11 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-11 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-11 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-11 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-19 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-19 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-19 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-19 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-19 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-20 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-20 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-21 09:00] Grado: 12vo grado | Materia: Química (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-24 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-24 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-24 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-24 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-24 14:00] Grado: 11vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-25 09:00] Grado: 12vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-26 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-26 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-26 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-27 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-27 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-27 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-27 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-27 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#
#
# --- DECEMBER 2025 ---
#   [2025-12-01 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-01 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-02 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-02 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-02 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-02 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-02 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-08 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-08 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-08 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-08 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-08 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-10 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-11 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-11 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-11 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-16 09:00] Grado: 12vo grado | Materia: Química (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-18 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-19 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-19 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-19 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-19 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-19 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-24 09:00] Grado: 12vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-25 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-25 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-25 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-25 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-25 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-26 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-26 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-26 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-26 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-26 14:00] Grado: 11vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-29 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-29 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-30 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-30 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-30 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-30 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-30 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #5) | Instructor: Alvaro Gonzalez
#
#
# --- JANUARY 2026 ---
#   [2026-01-02 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-02 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-02 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-02 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-02 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-05 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-05 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-06 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-06 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-06 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-07 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-07 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-07 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-07 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-07 14:00] Grado: 11vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-08 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-08 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-08 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-08 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-08 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-09 09:00] Grado: 12vo grado | Materia: Química (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-12 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-12 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-12 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-12 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-12 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-13 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-13 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-13 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-13 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-13 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-15 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-15 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-15 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-15 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-15 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-20 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-21 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-27 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-28 09:00] Grado: 12vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-29 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-29 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#
#
# --- FEBRUARY 2026 ---
#   [2026-02-02 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-02 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-02 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-02 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-02 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-03 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-05 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-05 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-05 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-05 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-05 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-09 09:00] Grado: 12vo grado | Materia: Química (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-11 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-12 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-13 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-13 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-17 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-17 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-17 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-19 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-19 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-19 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-19 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-19 14:00] Grado: 11vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-23 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-23 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-24 09:00] Grado: 12vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-25 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-25 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-26 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-26 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-26 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-26 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-26 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-27 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-27 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-27 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-27 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-27 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#
#
# --- MARCH 2026 ---
#   [2026-03-02 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-03 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-04 09:00] Grado: 12vo grado | Materia: Química (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-05 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-05 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-05 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-05 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-05 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-10 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-10 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-10 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-10 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-10 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-12 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-13 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-13 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-13 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-13 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-13 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-19 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-19 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-19 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-19 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-19 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-20 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-20 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-23 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-23 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-23 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-23 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-23 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-24 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-24 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-24 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-25 09:00] Grado: 12vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-26 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-26 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-31 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-31 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-31 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-31 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-31 14:00] Grado: 11vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#
#
# --- APRIL 2026 ---
#   [2026-04-01 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-03 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-03 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-03 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-03 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-03 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-06 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-06 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-06 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-09 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-09 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-09 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-09 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-09 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-10 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-10 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-10 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-10 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-10 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-13 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-13 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-15 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-16 09:00] Grado: 12vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-20 09:00] Grado: 12vo grado | Materia: Química (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-22 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-22 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-27 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-28 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-28 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-28 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-28 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-28 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-29 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-29 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-29 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-29 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-29 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-30 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-30 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-30 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-30 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-30 14:00] Grado: 11vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#
#
# --- MAY 2026 ---
#   [2026-05-04 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-06 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-06 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-06 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-06 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-06 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-07 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-07 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-08 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-08 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-11 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-12 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-14 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-14 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-14 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-14 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-14 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-15 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-15 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-15 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-15 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-15 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-20 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-20 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-20 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-20 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-20 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-21 09:00] Grado: 12vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-22 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-22 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-22 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-22 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-22 14:00] Grado: 11vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-27 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-27 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-27 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-28 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-28 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-28 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-28 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-28 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-29 09:00] Grado: 12vo grado | Materia: Química (Encuentro #10) | Instructor: Ivonne Blanco
#
# ================================================================================
# ✅ ¡Cronograma anual exportado exitosamente a 'Cronograma_Anual_2025-26.xlsx'!
# ================================================================================

# %%
import calendar
import datetime
import pandas as pd
import os
from collections import defaultdict
import random # Importar la biblioteca random

# Nota: Este script requiere la biblioteca pandas.
# Puedes instalarla con el comando: pip install pandas openpyxl

def generar_cronograma_mensual(materias, anio, mes, contador_encuentros):
    """
    Genera un cronograma de encuentros para un mes específico, actualizando el contador.

    Args:
        materias (list): Lista de materias a agendar para el mes.
        anio (int): El año para el cual se generará el cronograma.
        mes (int): El mes (en número) para el cual se generará el cronograma.
        contador_encuentros (defaultdict): Diccionario para llevar la cuenta de los
                                           encuentros por materia.

    Returns:
        tuple: Una tupla conteniendo dos listas:
               - cronograma_mes (list): Los encuentros agendados para el mes.
               - sin_agendar_mes (list): Las materias que no pudieron ser agendar.
    """
    # --- 1. Definición de Horarios y Constantes ---
    HORAS_DISPONIBLES = [9, 10, 11, 13, 14, 15]
    DIAS_SEMANA = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes"]

    # --- 2. Inicialización de Estructuras de Datos para el mes ---
    cronograma_mes = []
    sin_agendar_mes = []
    reuniones_instructor_dia = {}
    reuniones_grado_dia = {}
    horarios_ocupados = {}

    # --- 3. Generar la Lista de Días Hábiles del Mes ---
    dias_habiles_del_mes = []
    cal = calendar.Calendar()
    for dia in cal.itermonthdates(anio, mes):
        if dia.month == mes and dia.weekday() < 5:
            dias_habiles_del_mes.append(dia)

    # --- Barajar la lista de días hábiles para distribuir los encuentros ---
    random.shuffle(dias_habiles_del_mes)

    # --- 4. Algoritmo de Asignación Mensual ---
    for materia_info in materias:
        instructor = materia_info['instructor']
        grado = materia_info['grado']
        materia_nombre = materia_info['materia']

        encuentro_agendado = False

        # Iterar sobre los días hábiles (ahora barajados)
        for dia in dias_habiles_del_mes:
            dia_str = dia.strftime('%Y-%m-%d')
            for hora in HORAS_DISPONIBLES:

                if reuniones_instructor_dia.get(instructor, {}).get(dia_str, 0) >= 2:
                    continue
                if reuniones_grado_dia.get(grado, {}).get(dia_str, 0) >= 1:
                    continue
                if hora in horarios_ocupados.get(dia_str, []):
                    continue

                # --- Asignación del Encuentro ---
                # Se encontró un espacio. Se procede a agendar.

                # Incrementar y obtener el número de encuentro para esta materia
                llave_materia = (grado, materia_nombre)
                contador_encuentros[llave_materia] += 1
                numero_encuentro = contador_encuentros[llave_materia]

                cronograma_mes.append({
                    'fecha': dia_str,
                    'dia_semana': DIAS_SEMANA[dia.weekday()],
                    'hora_inicio': f"{hora:02d}:00",
                    'hora_fin': f"{hora+1:02d}:00",
                    'instructor': instructor,
                    'materia': materia_nombre,
                    'grado': grado,
                    'encuentro_nro': numero_encuentro
                })

                # Actualizar estructuras de control
                reuniones_instructor_dia.setdefault(instructor, {}).setdefault(dia_str, 0)
                reuniones_instructor_dia[instructor][dia_str] += 1
                reuniones_grado_dia.setdefault(grado, {}).setdefault(dia_str, 0)
                reuniones_grado_dia[grado][dia_str] += 1
                horarios_ocupados.setdefault(dia_str, []).append(hora)

                encuentro_agendado = True
                break

            if encuentro_agendado:
                break

        if not encuentro_agendado:
            sin_agendar_mes.append({**materia_info, 'mes_fallido': f"{mes}-{anio}"})

    return cronograma_mes, sin_agendar_mes

def imprimir_cronograma_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Imprime el cronograma anual de forma legible en la consola."""
    periodo = f"{mes_inicio}/{anio_inicio} - {mes_fin}/{anio_fin}"
    print("\n" + "="*80)
    print(f"CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO {periodo}")
    print("="*80)

    if not cronograma:
        print("No se pudo agendar ningún encuentro.")
        return

    cronograma_ordenado = sorted(cronograma, key=lambda x: (x['fecha'], x['hora_inicio']))

    ultimo_mes_impreso = None
    for encuentro in cronograma_ordenado:
        mes_actual = datetime.datetime.strptime(encuentro['fecha'], '%Y-%m-%d').strftime('%B %Y')
        if mes_actual != ultimo_mes_impreso:
            print(f"\n\n--- {mes_actual.upper()} ---")
            ultimo_mes_impreso = mes_actual

        print(
            f"  [{encuentro['fecha']} {encuentro['hora_inicio']}] "
            f"Grado: {encuentro['grado']:<10} | "
            f"Materia: {encuentro['materia']} (Encuentro #{encuentro['encuentro_nro']}) | "
            f"Instructor: {encuentro['instructor']}"
        )

    if sin_agendar:
        print("\n" + "="*80)
        print("ATENCIÓN: Los siguientes encuentros no pudieron ser agendados:")
        print("="*80)
        for item in sin_agendar:
            print(f"- Mes: {item['mes_fallido']} | Grado: {item['grado']}, Materia: {item['materia']}, Instructor: {item['instructor']}")

def exportar_a_excel_anual(cronograma, sin_agendar, anio_inicio, mes_inicio, anio_fin, mes_fin):
    """Exporta el cronograma anual a un archivo Excel."""
    if not cronograma:
        print("\nNo hay datos para exportar a Excel.")
        return

    datos_para_df = []
    for item in cronograma:
        datos_para_df.append({
            'Fecha': item['fecha'],
            'Hora': f"{item['hora_inicio']} - {item['hora_fin']}",
            'Grado': item['grado'],
            'Materia': item['materia'],
            'Encuentro Nro': item['encuentro_nro'],
            'Instructor': item['instructor']
        })

    df_cronograma = pd.DataFrame(datos_para_df)
    df_cronograma = df_cronograma.sort_values(by=['Fecha', 'Hora']).reset_index(drop=True)

    periodo_str = f"{anio_inicio}-{anio_fin if anio_inicio == anio_fin else str(anio_fin)[-2:]}"
    nombre_archivo = f"Cronograma_Anual_{periodo_str}.xlsx"

    with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:
        df_cronograma.to_excel(writer, sheet_name='Cronograma Anual', index=False)
        if sin_agendar:
            df_sin_agendar = pd.DataFrame(sin_agendar)
            df_sin_agendar.to_excel(writer, sheet_name='No Agendados', index=False)

    print("\n" + "="*80)
    print(f"✅ ¡Cronograma anual exportado exitosamente a '{nombre_archivo}'!")
    print("="*80)

# --- EJECUCIÓN PRINCIPAL ---
if __name__ == "__main__":
    lista_de_materias = [
        {'instructor': 'Yosibel Garcia', 'materia': 'Cívica', 'grado': '7mo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '7mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '7no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '7mo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '7mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Lideres Emergentes', 'grado': '7mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '8vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '8vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Matemática', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias', 'grado': '8vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales', 'grado': '8vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación para la Salud', 'grado': '8vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Castellano', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '9no grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Álgebra I', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Biología', 'grado': '9no grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia de USA', 'grado': '9no grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Educación Física', 'grado': '9no grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '10mo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Geometría', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Ética', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '10mo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Orientación Vocacional', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia Univeral', 'grado': '10mo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Actuación', 'grado': '10mo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '11vo grado'},
        {'instructor': 'Osmary Mujica', 'materia': 'Inglés', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Algebra II', 'grado': '11vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Arte', 'grado': '11vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Finanzas Personales y Gestión del Dinero', 'grado': '11vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Historia del Arte', 'grado': '11vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Ciencias de la Tierra', 'grado': '11vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Castellano', 'grado': '12vo grado'},
        {'instructor': 'Jhonfrank Sanchez', 'materia': 'Inglés', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Ciencias de la Computación', 'grado': '12vo grado'},
        {'instructor': 'Freddy Martinez', 'materia': 'Física', 'grado': '12vo grado'},
        {'instructor': 'Yosibel Garcia', 'materia': 'Gobierno de USA', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Liderazgo', 'grado': '12vo grado'},
        {'instructor': 'Alvaro Gonzalez', 'materia': 'Economía', 'grado': '12vo grado'},
        {'instructor': 'Ivonne Blanco', 'materia': 'Química', 'grado': '12vo grado'}
    ]

    # --- Definir el período del año escolar ---
    ANIO_INICIO, MES_INICIO = 2025, 8  # Agosto 2025
    ANIO_FIN, MES_FIN = 2026, 5      # Mayo 2026

    # --- Preparar estructuras para el ciclo anual ---
    cronograma_anual_completo = []
    no_agendados_total = []
    contador_general_encuentros = defaultdict(int) # Usamos defaultdict para simplificar

    print("Iniciando generación de cronograma para el año escolar...")

    # --- Iterar a través de cada mes del año escolar ---
    anio_actual, mes_actual = ANIO_INICIO, MES_INICIO
    while (anio_actual, mes_actual) <= (ANIO_FIN, MES_FIN):
        print(f"\nProcesando mes: {mes_actual}/{anio_actual}...")

        cronograma_del_mes, no_agendados_del_mes = generar_cronograma_mensual(
            lista_de_materias, anio_actual, mes_actual, contador_general_encuentros
        )

        cronograma_anual_completo.extend(cronograma_del_mes)
        no_agendados_total.extend(no_agendados_del_mes)

        # Avanzar al siguiente mes
        mes_actual += 1
        if mes_actual > 12:
            mes_actual = 1
            anio_actual += 1

    # --- Mostrar y exportar resultados finales ---
    imprimir_cronograma_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
    exportar_a_excel_anual(cronograma_anual_completo, no_agendados_total, ANIO_INICIO, MES_INICIO, ANIO_FIN, MES_FIN)
# Out:
# Iniciando generación de cronograma para el año escolar...
#
# Procesando mes: 8/2025...
#
# Procesando mes: 9/2025...
#
# Procesando mes: 10/2025...
#
# Procesando mes: 11/2025...
#
# Procesando mes: 12/2025...
#
# Procesando mes: 1/2026...
#
# Procesando mes: 2/2026...
#
# Procesando mes: 3/2026...
#
# Procesando mes: 4/2026...
#
# Procesando mes: 5/2026...
#
# ================================================================================
# CRONOGRAMA ANUAL DE ENCUENTROS SINCRÓNICOS - PERÍODO 8/2025 - 5/2026
# ================================================================================
#
#
# --- AUGUST 2025 ---
#   [2025-08-01 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-01 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-05 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-06 09:00] Grado: 12vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-11 09:00] Grado: 12vo grado | Materia: Química (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-12 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-12 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-12 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-12 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-12 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-13 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-13 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-13 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-13 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-13 14:00] Grado: 11vo grado | Materia: Física (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-15 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-15 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-15 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-15 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-15 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-18 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-18 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-20 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-20 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-20 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-20 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-20 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-22 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-22 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-22 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-22 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-22 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-25 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #1) | Instructor: Ivonne Blanco
#   [2025-08-25 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-25 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #1) | Instructor: Osmary Mujica
#   [2025-08-25 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #1) | Instructor: Freddy Martinez
#   [2025-08-25 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#   [2025-08-26 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #1) | Instructor: Alvaro Gonzalez
#   [2025-08-28 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-29 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-29 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #1) | Instructor: Yosibel Garcia
#   [2025-08-29 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #1) | Instructor: Jhonfrank Sanchez
#
#
# --- SEPTEMBER 2025 ---
#   [2025-09-02 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-02 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-02 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-02 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-02 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-04 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-04 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-04 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-04 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-04 14:00] Grado: 11vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-05 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-05 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-05 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-08 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-09 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-09 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-09 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-09 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-09 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-10 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-10 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-10 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-10 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-10 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #2) | Instructor: Osmary Mujica
#   [2025-09-11 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-11 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-11 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-11 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-11 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-15 09:00] Grado: 12vo grado | Materia: Química (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-16 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-16 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #2) | Instructor: Freddy Martinez
#   [2025-09-18 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-19 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-19 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #2) | Instructor: Jhonfrank Sanchez
#   [2025-09-25 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-25 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-25 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #2) | Instructor: Ivonne Blanco
#   [2025-09-25 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-25 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #2) | Instructor: Alvaro Gonzalez
#   [2025-09-26 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #2) | Instructor: Yosibel Garcia
#   [2025-09-29 09:00] Grado: 12vo grado | Materia: Física (Encuentro #2) | Instructor: Freddy Martinez
#
#
# --- OCTOBER 2025 ---
#   [2025-10-01 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-01 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-03 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-03 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-03 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-03 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-03 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-06 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-07 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-07 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-07 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-07 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-07 14:00] Grado: 11vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-08 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-13 09:00] Grado: 12vo grado | Materia: Física (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-14 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-14 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-14 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-14 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-14 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-16 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-17 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-17 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-20 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-20 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-20 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-20 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-20 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-21 09:00] Grado: 12vo grado | Materia: Química (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-23 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-23 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-23 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-29 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-29 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-29 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #3) | Instructor: Ivonne Blanco
#   [2025-10-29 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-29 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #3) | Instructor: Alvaro Gonzalez
#   [2025-10-31 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #3) | Instructor: Yosibel Garcia
#   [2025-10-31 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #3) | Instructor: Freddy Martinez
#   [2025-10-31 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #3) | Instructor: Jhonfrank Sanchez
#   [2025-10-31 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #3) | Instructor: Osmary Mujica
#   [2025-10-31 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #3) | Instructor: Osmary Mujica
#
#
# --- NOVEMBER 2025 ---
#   [2025-11-03 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-03 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-03 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-03 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-03 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-04 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-04 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-04 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-04 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-04 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-05 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-05 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-05 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-05 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-05 14:00] Grado: 11vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-06 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-06 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-06 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-11 09:00] Grado: 12vo grado | Materia: Física (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-13 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-13 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-13 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-13 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-13 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-18 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-18 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-18 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-18 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-18 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #4) | Instructor: Osmary Mujica
#   [2025-11-19 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-19 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #4) | Instructor: Jhonfrank Sanchez
#   [2025-11-20 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-20 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-20 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-20 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #4) | Instructor: Yosibel Garcia
#   [2025-11-20 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-21 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-25 09:00] Grado: 12vo grado | Materia: Química (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-26 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #4) | Instructor: Alvaro Gonzalez
#   [2025-11-27 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #4) | Instructor: Ivonne Blanco
#   [2025-11-27 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #4) | Instructor: Freddy Martinez
#   [2025-11-28 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #4) | Instructor: Yosibel Garcia
#
#
# --- DECEMBER 2025 ---
#   [2025-12-03 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-03 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-03 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-03 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-03 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-05 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-05 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-05 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-05 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-05 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-09 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-09 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-09 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-09 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-09 14:00] Grado: 11vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-10 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-10 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-10 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-10 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-10 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-11 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-11 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-12 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-15 09:00] Grado: 12vo grado | Materia: Química (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-17 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-18 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-18 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-18 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-18 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-18 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-22 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-22 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-22 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-25 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #5) | Instructor: Yosibel Garcia
#   [2025-12-25 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-25 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #5) | Instructor: Jhonfrank Sanchez
#   [2025-12-25 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-25 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #5) | Instructor: Osmary Mujica
#   [2025-12-29 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #5) | Instructor: Alvaro Gonzalez
#   [2025-12-30 09:00] Grado: 12vo grado | Materia: Física (Encuentro #5) | Instructor: Freddy Martinez
#   [2025-12-31 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #5) | Instructor: Ivonne Blanco
#   [2025-12-31 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #5) | Instructor: Freddy Martinez
#
#
# --- JANUARY 2026 ---
#   [2026-01-05 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-05 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-05 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-05 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-05 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-06 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-06 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-07 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-07 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-07 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-07 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-07 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-08 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-08 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-08 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-08 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-08 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-14 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-16 09:00] Grado: 12vo grado | Materia: Química (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-21 09:00] Grado: 12vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-22 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-22 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-22 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-22 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-22 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #6) | Instructor: Freddy Martinez
#   [2026-01-23 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-23 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-23 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-23 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-23 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-26 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-27 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-27 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-27 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-28 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #6) | Instructor: Yosibel Garcia
#   [2026-01-28 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #6) | Instructor: Jhonfrank Sanchez
#   [2026-01-29 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-30 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #6) | Instructor: Osmary Mujica
#   [2026-01-30 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-30 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #6) | Instructor: Ivonne Blanco
#   [2026-01-30 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #6) | Instructor: Alvaro Gonzalez
#   [2026-01-30 14:00] Grado: 11vo grado | Materia: Física (Encuentro #6) | Instructor: Freddy Martinez
#
#
# --- FEBRUARY 2026 ---
#   [2026-02-02 09:00] Grado: 12vo grado | Materia: Química (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-05 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-05 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-05 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-05 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-05 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-06 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-06 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-09 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-09 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-09 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-11 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-11 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-12 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-13 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-13 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-13 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-16 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-16 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-16 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-16 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-16 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #7) | Instructor: Jhonfrank Sanchez
#   [2026-02-17 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-18 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-18 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-18 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-18 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-18 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-19 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-19 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-19 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-19 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #7) | Instructor: Yosibel Garcia
#   [2026-02-19 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-24 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #7) | Instructor: Osmary Mujica
#   [2026-02-24 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-24 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #7) | Instructor: Ivonne Blanco
#   [2026-02-24 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-24 14:00] Grado: 11vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#   [2026-02-25 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #7) | Instructor: Alvaro Gonzalez
#   [2026-02-27 09:00] Grado: 12vo grado | Materia: Física (Encuentro #7) | Instructor: Freddy Martinez
#
#
# --- MARCH 2026 ---
#   [2026-03-02 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-02 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-09 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-09 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-09 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-09 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-09 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-10 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-10 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-11 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-11 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-11 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-11 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-11 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-12 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-12 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-12 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-12 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-12 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-13 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-13 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-13 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-13 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-13 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-16 09:00] Grado: 12vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-17 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-17 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-17 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #8) | Instructor: Jhonfrank Sanchez
#   [2026-03-18 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-19 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-20 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-20 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-20 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-20 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #8) | Instructor: Alvaro Gonzalez
#   [2026-03-20 14:00] Grado: 11vo grado | Materia: Física (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-24 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-26 09:00] Grado: 12vo grado | Materia: Química (Encuentro #8) | Instructor: Ivonne Blanco
#   [2026-03-31 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#   [2026-03-31 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-31 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #8) | Instructor: Freddy Martinez
#   [2026-03-31 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #8) | Instructor: Yosibel Garcia
#   [2026-03-31 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #8) | Instructor: Osmary Mujica
#
#
# --- APRIL 2026 ---
#   [2026-04-01 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-01 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-01 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-01 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-01 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-02 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-03 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-06 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-06 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-06 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-06 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-06 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-07 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-07 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-08 09:00] Grado: 12vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-09 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-09 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-09 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-09 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-09 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-10 09:00] Grado: 12vo grado | Materia: Química (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-14 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-14 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-14 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-15 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-15 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-22 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-24 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-24 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-24 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-24 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-24 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #9) | Instructor: Jhonfrank Sanchez
#   [2026-04-29 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #9) | Instructor: Osmary Mujica
#   [2026-04-29 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-29 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-29 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #9) | Instructor: Alvaro Gonzalez
#   [2026-04-29 14:00] Grado: 11vo grado | Materia: Física (Encuentro #9) | Instructor: Freddy Martinez
#   [2026-04-30 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-30 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-30 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #9) | Instructor: Ivonne Blanco
#   [2026-04-30 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #9) | Instructor: Yosibel Garcia
#   [2026-04-30 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #9) | Instructor: Alvaro Gonzalez
#
#
# --- MAY 2026 ---
#   [2026-05-01 09:00] Grado: 11vo grado | Materia: Ciencias de la Tierra (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-01 10:00] Grado: 12vo grado | Materia: Ciencias de la Computación (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-08 09:00] Grado: 12vo grado | Materia: Gobierno de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-11 09:00] Grado: 12vo grado | Materia: Economía (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-13 09:00] Grado: 11vo grado | Materia: Historia del Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-13 10:00] Grado: 12vo grado | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-14 09:00] Grado: 12vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-15 09:00] Grado: 12vo grado | Materia: Liderazgo (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-18 09:00] Grado: 7mo grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-18 10:00] Grado: 8vo grado  | Materia: Finanzas Personales (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-18 11:00] Grado: 9no grado  | Materia: Biología (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-18 13:00] Grado: 10mo grado | Materia: Orientación Vocacional (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-18 14:00] Grado: 11vo grado | Materia: Física (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-19 09:00] Grado: 7mo grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-19 10:00] Grado: 8vo grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-19 11:00] Grado: 9no grado  | Materia: Álgebra I (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-19 13:00] Grado: 10mo grado | Materia: Ética (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-19 14:00] Grado: 11vo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-21 09:00] Grado: 12vo grado | Materia: Química (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-22 09:00] Grado: 7mo grado  | Materia: Cívica (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-22 10:00] Grado: 7no grado  | Materia: Matemática (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-22 11:00] Grado: 8vo grado  | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-22 13:00] Grado: 9no grado  | Materia: Castellano (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-22 14:00] Grado: 10mo grado | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-25 09:00] Grado: 7mo grado  | Materia: Lideres Emergentes (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-25 10:00] Grado: 8vo grado  | Materia: Educación para la Salud (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-25 11:00] Grado: 9no grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-25 13:00] Grado: 10mo grado | Materia: Historia Univeral (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-25 14:00] Grado: 11vo grado | Materia: Finanzas Personales y Gestión del Dinero (Encuentro #10) | Instructor: Alvaro Gonzalez
#   [2026-05-26 09:00] Grado: 7mo grado  | Materia: Educación Física (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-26 10:00] Grado: 8vo grado  | Materia: Inglés (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-26 11:00] Grado: 9no grado  | Materia: Inglés (Encuentro #10) | Instructor: Osmary Mujica
#   [2026-05-26 13:00] Grado: 10mo grado | Materia: Geometría (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-26 14:00] Grado: 11vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#   [2026-05-27 09:00] Grado: 7mo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-27 10:00] Grado: 8vo grado  | Materia: Ciencias (Encuentro #10) | Instructor: Ivonne Blanco
#   [2026-05-27 11:00] Grado: 9no grado  | Materia: Historia de USA (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-27 13:00] Grado: 10mo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-27 14:00] Grado: 11vo grado | Materia: Algebra II (Encuentro #10) | Instructor: Freddy Martinez
#   [2026-05-29 09:00] Grado: 10mo grado | Materia: Actuación (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-29 10:00] Grado: 11vo grado | Materia: Arte (Encuentro #10) | Instructor: Yosibel Garcia
#   [2026-05-29 11:00] Grado: 12vo grado | Materia: Castellano (Encuentro #10) | Instructor: Jhonfrank Sanchez
#
# ================================================================================
# ✅ ¡Cronograma anual exportado exitosamente a 'Cronograma_Anual_2025-26.xlsx'!
# ================================================================================
